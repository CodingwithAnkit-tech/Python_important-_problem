# %%
# 1) Check if a number is even or odd.

def even_odd():
    n = int(input("Enter number: "))
    print("Even" if n % 2 == 0 else "Odd")

even_odd()
# Out:
# Odd

# %%
# 2) Check if a person is eligible to vote (age ≥ 18).

def vote_eligible():
    age = int(input("Enter age: "))
    print("Eligible" if age>18 else "not Eligible")
vote_eligible()
# Out:
# Eligible

# %%
# 3) Check if a number is positive or not. 

def positive_negative():
     n = int(input("Enter number: "))
     return ("postive" if n>0 else "negative")
positive_negative()
# Out:
# 'postive'

# %%
# 4) Check if two numbers are equal or not.
def equal_not():
    n1 = int(input("Enter number: "))
    n2 = int(input("Enter number: "))
    return('equal' if n1 == n2 else 'not equal')

equal_not()
# Out:
# 'equal'

# %%
# 5) Check if a number is divisible by 5. 
def divisible():
    n = int(input("Enter number: "))
    return("Divisible by 5" if n % 5 == 0 else "not divisible")
divisible()
# Out:
# 'Divisible by 5'

# %%
# 6) Check if a character is a vowel or consonant. 

def vowel_constant():
     char = input("Enter string: ")
     return ("vowel" if char in 'aeiouAEIOU' else "constant")
vowel_constant()
# Out:
# 'constant'

# %%
# 7) Check if a number is within a range (1–100).

def  in_range():
    n = int(input("Enter number: "))
    return("in range" if 1 < n < 100 else "out of range")
in_range()
# Out:
# 'in range'

# %%
# 8) Check if a string is empty or not.  

def string_empty():
    str = input("enter string:")
    return("string empty" if str == "" else "not empty")
string_empty()
# Out:
# 'string empty'

# %%
# 9) Check if a number is a multiple of 3.

def multiple_of_3():
    n = int(input("Enter number: "))
    print("Multiple of 3" if n % 3 == 0 else "Not multiple")

multiple_of_3()
# Out:
# Multiple of 3

# %%
# 10) Check if a password is correct.

def password_check():
    password = input("Enter the password: ")
    return("password is correct" if password == 'ankit@26132' else"incorrect")
password_check()
# Out:
# 'password is correct'

# %%
#11) Check if a number is greater than 100.
def greater_than_100():
    num = int(input("Enter the number:"))
    return("grater than 100" if num > 100 else "not grater than 100")
greater_than_100()
# Out:
# 'not grater than 100'

# %%
# 12) Check if a number is negative.

def negative_number():
   num = int(input("Enter the number:"))
   return("negative number" if num < 0 else "postive number")
negative_number()
# Out:
# 'postive number'

# %%
# 13.Check if a number is a two-digit number. 

def two_digit_number():
    n = int(input("Enter the number:"))
    return("yes two digit number" if 9 < n < 100 else "not two digit number")
two_digit_number()
# Out:
# 'not two digit number'

# %%
# 14.Check if a person is tall (height > 170 cm).

def person_is_tall():
     h = int(input("Enter the hight(cm):"))
     return("Tall" if h > 170 else "Not tall")
person_is_tall()
# Out:
# 'Tall'

# %%
# 15.Check if one number is the square of another.

def square_check():
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print("Square relation" if a*a == b or b*b == a else "No relation")

square_check()
# Out:
# No relation

# %%
# 16.Check if the temperature is above the freezing point.

def freezing_point():
    temp = int(input("Enter temperature: "))
    print("Above freezing" if temp > 0 else "Freezing or below")

freezing_point()
# Out:
# Freezing or below

# %%
# 17.Check if a given year is before or after 2000. 

def year_before_after():
    year = int(input("Enter the year :"))
    return("before 2000"  if year < 2000 else "after 2000")
year_before_after()
# Out:
# 'before 2000'

# %%
# 18.Check if a student passed (marks ≥ 40).

def student():
    marks = int(input("Enter the marks:"))
    return("passed" if marks>=40 else "fail")
# Out:
# Before 2000

# %%
# Check if an entered letter is uppercase or not.

def upper_case():
    char = input("Enter the charcter :")
    return("upper case" if char.isupper() else "lower case")

upper_case()
# Out:
# 'lower case'

# %%
# 21.WAP to check the year is a leap year or not .

def leap_year():
    year = int(input("Enter the year: "))
    return("leap year" if year % 4 == 0 and year % 100 !=0 or year % 400 == 0 else "not leap year")
leap_year()
# Out:
# 'leap year'

# %%
# # 19.Check if a given number is less than 10 or not.

def less_than_10():
    n = int(input("Enter number: "))
    print("Less than 10" if n < 10 else "10 or more")

less_than_10()
