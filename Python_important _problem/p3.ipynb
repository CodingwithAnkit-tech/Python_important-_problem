# %%
# 1) Number between 50 and 100

n = int(input("Enter the number: "))
if 50 < n < 100:
    print("Between 50 and 100")
# Out:
# Between 50 and 100

# %%
# 2) String has more than 3 characters

s = input("Enter a string:")
if len(s)>3:
    print("more than 3 character")
# Out:
# more than 3 character

# %%
# 3) Number has 4 digits

n = int(input("Enter the number:"))
if 1000<n<9999:
    print("4 digit number")
# Out:
# 4 digit number

# %%
# 4) character is vowel

s = input("Enter a charcter:")
if s in 'aeiouAEIOU':
    print("character is vowel")
# Out:
# character is vowel

# %%
#5) Character is consonant

s = input("Enter a charcter:")
if s not in 'aeiouAEIOU':
    print("character is constant")
# Out:
# character is constant

# %%
#5) Character is consonant

ch = input().lower()
if ch.isalpha() and ch not in "aeiou":
    print("Consonant")
# Out:
# Consonant

# %%
# 6) Multiply of 6 .

n = int(input("Enter the  number:"))
if n%5==0:
    print("Yes mutliply of 5")
# Out:
# Yes mutliply of 5

# %%
# 7) Uppercase alphabet

char = input("Enter character:")
if char.isupper():
    print("upper case")
# Out:
# upper case

# %%
# 8) Lowercase alphabet

char = input("Enter character:")
if char.islower():
    print("lower case")
# Out:
# lower case

# %%
# 9) Character is number

char = input()
if char.isdigit():
    print("Digit")
# Out:
# Digit

# %%
# 10) Check float datatype

x =float(input("Enter a number:"))

if isinstance(x, float):  

    print("Float type")
# Out:
# Float type

# %%
# 11) Number is positive

n = int(input("Enter a number:"))
if n > 0:
    print("number is positive")
# Out:
# number is positive

# %%
# 12) number is even

n = int(input("Enter a number:"))
if n % 2== 0:
    print("number is even")
# Out:
# number is even

# %%
# 13) Age check

age = int(input("Enter a number:"))
if  age > 18:
    print("You are adult")
# Out:
# You are adult

# %%
# 14) Temperature check

temp = (int(input()))

if temp < 15:
    print("It is code")
# Out:
# It is code

# %%
# 15) String equals "hello"

s = input()
if s == "hello":
    print("Greeting detected!")
# Out:
# Greeting detected!
