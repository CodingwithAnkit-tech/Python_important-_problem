# %% [markdown]
# # Q-1> WHAT IS PYTHON?
#       It is general-purpose programming language.
#       it is interpreted,object-oriented, high-level language.
#       It is platform independent,widely used in AI,ML.
#       It is used to develpe almost any type of application.
#       it is easy to learn and require less code to develop the app.
#       it consists of many libraries and inbuilt functions that make it easy to maintain and portable.

# %% [markdown]
# # Q-2> WHAT ARE THE ADVANTAGES OF PYTHON?
#
#       It is free and open source.
#       it is portable.
#       it is extensible.
#       it is objected oriented .
#       it is built in data structure.

# %% [markdown]
# # Q-3> WHAT IS PEP 8?
#
#     ANS:-PEP 8 is a coding convention which specifies a set of guidelines, about how to write your python
#      code more readable.

# %% [markdown]
# -  1.Wap to check the no. is lying between 50 and 100
#  - 2.Check the given string is having more than
#  - 3 characters. 3.Wap to check the no. is having 4 digits.
#  - 4.Wap to check whether the given character is vowel.
#  - 5.Wap to check whether the given character is consonant .
#  - 6.Wap to check the whether the no. is multiple of 5 .
#  - 7.Wap to check the given character is uppercase alphabet
#  - 8.Wap to check the given character is lower case alphabet
#  - 9.Wap to check the given character is a number.
#  - 10.Wap to check whether the given data is float data type .
#  - 11.Write a Python program that checks if a number is positive.
#  - 12.Write a Python program to check if a number is even.
#  - 13.Ask the user to input their age, and print "You are an adult" if age is 18 or older.
#  - 14.Take input for a temperature value, and print "It's cold" if the temperature is below 15.
#  - 15.Check if a string variable is equal to "hello" and print "Greeting detected!" if it is. ============================================================================

# %% [markdown]
# = =================== =>if-else :- ~~~~~~~~~~~
# - 1.Check if a number is even or odd.
# - 2.Check if a person is eligible to vote (age ≥ 18).
# - 3.Check if a number is positive or not.
# - 4.Check if two numbers are equal or not.
# - 5.Check if a number is divisible by 5.
# - 6.Check if a character is a vowel or consonant.
# - 7.Check if a number is within a range (1–100).
# - 8.Check if a string is empty or not.
# - 9.Check if a number is a multiple of 3.
# - 10.Check if a password is correct.
# - 11.Check if a number is greater than 100.
# - 12.Check if a number is negative.
# - 13.Check if a number is a two-digit number.
# - 14.Check if a person is tall (height > 170 cm).
# - 15.Check if one number is the square of another.
# - 16.Check if the temperature is above the freezing point.
# - 17.Check if a given year is before or after 2000.
# - 18.Check if a student passed (marks ≥ 40).
# - 19.Check if a given number is less than 10 or not.
